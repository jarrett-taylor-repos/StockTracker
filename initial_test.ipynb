# %%
import pandas as pd
import mplfinance as mpf

# %%
daily = pd.read_csv('AAPL.csv', index_col=0, parse_dates=True)
# daily.index.name='Date'
daily.loc[daily.index > '2023-01-01']
# daily
# Out:
#              Close    Volume    Open    High      Low
# Date
# 2024-07-05   76.05   9663107   76.24   76.27   75.420
# 2024-07-03   76.26   4906747   76.84   77.04   76.070
# 2024-07-02   76.83   8854084   77.12   77.21   76.280
# 2024-07-01   77.13   6767590   77.99   78.22   76.780
# 2024-06-28   77.85  13207540   78.72   78.88   77.610
# ...            ...       ...     ...     ...      ...
# 2023-01-09  104.74  10124760  106.52  106.68  104.431
# 2023-01-06  106.69   9644109  105.38  107.00  105.010
# 2023-01-05  104.43   5575086  104.49  105.10  103.490
# 2023-01-04  104.46   8166646  102.69  104.73  102.550
# 2023-01-03  100.83   6607675  100.56  101.17   99.470
#
# [378 rows x 5 columns]

# %%
start_date = '2022-01-01' 
end_date = '2024-01-01' 
data = daily.loc[(daily.index > start_date) & (daily.index <= end_date)]
mpf.plot(data, mav=(50,200))
